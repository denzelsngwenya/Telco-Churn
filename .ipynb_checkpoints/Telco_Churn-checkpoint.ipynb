# %% [markdown]
# ## About TELCO CHURN
#
# In this project we will analyse the Telco Churn Data. Where, Telco is a fictional telecommunications company that provides home phone and internet services. The data therefore contains:
# <ol>
#     <li> Customers who left the company within the last month.
#     <li> Customers' about information such as gender, customer ID, Monthly and Total Charges and many more which you will see in the data description.
#     <li> Customer demographics i.e age, gender, and whether or not they have dependents.
# </ol>
#
# More information about the Telco Data set can be found in [IBM](https://community.ibm.com/community/user/businessanalytics/blogs/steven-macko/2019/07/11/telco-customer-churn-1113). Here, we will analyse the data, by first cleaning it and then apply some Machine Learning techniques to try and predict Churn rate for Telco.

# %%
##=======================================================
#                 IMPORT LIBRARIES 
##=======================================================


## Basics 
import numpy as np
import pandas as pd

## Visualization
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns

## ML
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest
from sklearn.compose import ColumnTransformer
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, plot_roc_curve

# %%
# Import Data using Pandas data frames

data = pd.read_csv('Telco-Customer-Churn.csv')
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# Check for missing values in our data frame

data.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Check the data types of the columns
print("hello")

# %%
# Change the columns into appropriate data types

# %%
# Fill in missing values if they are there, otherwise drop this cell

# %%
# Plot some graphs of interest
